# %% [markdown]
# # First Post

# %% [markdown]
# This is a *first post* testing the use of **IPython Notebook** for blogging purposes.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %% [markdown]
# ## Random data

# %%
x = np.linspace(0,100)
y = x**1.2 + (np.random.rand(50)-0.5)*80
plt.plot(x,y,'.-')

# %% [markdown]
# We do also need to test some math desperately:
# $$f(x) = \frac{1+x}{1-\frac{x}{1-x^2}}$$
